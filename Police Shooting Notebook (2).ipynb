# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import datetime
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs
import seaborn as sns



# %matplotlib inline

df = pd.read_csv('Documents/Police Shooting data.csv', encoding='latin-1' )
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  1/2/2015              shot         gun  53.0
# 1   4    Lewis Lee Lembke  1/2/2015              shot         gun  47.0
# 2   5  John Paul Quintero  1/3/2015  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  1/4/2015              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  1/4/2015              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %% [markdown]
# ###First I want to explore the data for a better understanding of the data, find any NAs, see what is in the columns, etc.

# %%
#First I want to explore the data
df.shape
# Out:
# (4453, 14)

# %%
#columns with missing data
NullColumns = set(df.columns[np.sum(df.isnull()) == 0])

# %%
NullColumns
# Out:
# {'body_camera',
#  'city',
#  'date',
#  'id',
#  'manner_of_death',
#  'name',
#  'signs_of_mental_illness',
#  'state',
#  'threat_level'}

# %%
#what percent of rows are missing for each column?
np.sum(df.isnull())/df.shape[0]*100
# Out:
# id                         0.000000
# name                       0.000000
# date                       0.000000
# manner_of_death            0.000000
# armed                      5.569279
# age                        3.772737
# gender                     0.089827
# race                       8.309005
# city                       0.000000
# state                      0.000000
# signs_of_mental_illness    0.000000
# threat_level               0.000000
# flee                       3.974848
# body_camera                0.000000
# dtype: float64

# %%
#Adding year column to data based on date column
df['year'] = pd.DatetimeIndex(df['date']).year
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  1/2/2015              shot         gun  53.0
# 1   4    Lewis Lee Lembke  1/2/2015              shot         gun  47.0
# 2   5  John Paul Quintero  1/3/2015  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  1/4/2015              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  1/4/2015              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  year
# 0  Not fleeing        False  2015
# 1  Not fleeing        False  2015
# 2  Not fleeing        False  2015
# 3  Not fleeing        False  2015
# 4  Not fleeing        False  2015

# %%
#Police Shootings by year
year_vals = df.year.value_counts().sort_index()

(year_vals).plot(kind="bar");
plt.title("Police Shooting by Year");

# %%
#Seeing what is in manner of death column.
MOD_vals = df.manner_of_death.value_counts().sort_index()

(MOD_vals).plot(kind="bar");
plt.title("Police Shooting by MOD");

# %%
#police shootings by year, filtered to African Americans
df_B= df.loc[df['race'] == "B"]

year_vals_B = df_B.year.value_counts().sort_index()

(year_vals_B).plot(kind="bar");
plt.title("Police Shooting by Year");

# %%
#police shootings by year, filtered to White people
df_W= df.loc[df['race'] == "W"]

year_vals_W = df_W.year.value_counts().sort_index()

(year_vals_W).plot(kind="bar");
plt.title("Police Shooting by Year");

# %% [markdown]
# ###I want to start preparing the data. Remove NAs where I need to, remove columns that are not usful, clean up other columns.

# %%
###Removing missing values

# %%
#Dropping rows that do not have a race value
df2= df.dropna(subset=['race'], how='any')

# %%
#Dropping all na
df3= df2.dropna()

# %%
#Dropping columns that are not valuable usefull for the analysis
df4= df3.drop(['name','date','manner_of_death','id','state'],axis=1)

# %%
#Seeing what all is in the armed column by creating a dataframe
armed_df = df4.armed.unique()

# %%
armed_df
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'shovel',
#        'hammer', 'hatchet', 'undetermined', 'sword', 'machete',
#        'box cutter', 'metal object', 'screwdriver', 'lawn mower blade',
#        'flagpole', 'guns and explosives', 'cordless drill', 'metal pole',
#        'Taser', 'metal pipe', 'metal hand tool', 'blunt object',
#        'metal stick', 'sharp object', 'meat cleaver', 'carjack', 'chain',
#        "contractor's level", 'unknown weapon', 'stapler', 'crossbow',
#        'bean-bag gun', 'baseball bat and fireplace poker',
#        'straight edge razor', 'gun and knife', 'ax', 'brick',
#        'baseball bat', 'hand torch', 'chain saw', 'garden tool',
#        'scissors', 'pole', 'pick-axe', 'flashlight', 'spear', 'chair',
#        'pitchfork', 'hatchet and gun', 'rock', 'piece of wood', 'bayonet',
#        'glass shard', 'motorcycle', 'pepper spray', 'metal rake', 'baton',
#        'crowbar', 'oar', 'machete and gun', 'air conditioner',
#        'pole and knife', 'beer bottle', 'pipe', 'baseball bat and bottle',
#        'fireworks', 'pen', 'chainsaw', 'gun and sword', 'gun and car',
#        'vehicle', 'pellet gun', 'BB gun', 'incendiary device',
#        'samurai sword', 'bow and arrow', 'gun and vehicle',
#        'vehicle and gun', 'wrench', 'walking stick', 'barstool'],
#       dtype=object)

# %%
#I've decided to condence this column down to armed and unarmed. First I am creating a df for anything other than armed. 
armed_df= armed_df[armed_df != "unarmed"]

# %%
armed_df
# Out:
# array(['gun', 'toy weapon', 'nail gun', 'knife', 'shovel', 'hammer',
#        'hatchet', 'undetermined', 'sword', 'machete', 'box cutter',
#        'metal object', 'screwdriver', 'lawn mower blade', 'flagpole',
#        'guns and explosives', 'cordless drill', 'metal pole', 'Taser',
#        'metal pipe', 'metal hand tool', 'blunt object', 'metal stick',
#        'sharp object', 'meat cleaver', 'carjack', 'chain',
#        "contractor's level", 'unknown weapon', 'stapler', 'crossbow',
#        'bean-bag gun', 'baseball bat and fireplace poker',
#        'straight edge razor', 'gun and knife', 'ax', 'brick',
#        'baseball bat', 'hand torch', 'chain saw', 'garden tool',
#        'scissors', 'pole', 'pick-axe', 'flashlight', 'spear', 'chair',
#        'pitchfork', 'hatchet and gun', 'rock', 'piece of wood', 'bayonet',
#        'glass shard', 'motorcycle', 'pepper spray', 'metal rake', 'baton',
#        'crowbar', 'oar', 'machete and gun', 'air conditioner',
#        'pole and knife', 'beer bottle', 'pipe', 'baseball bat and bottle',
#        'fireworks', 'pen', 'chainsaw', 'gun and sword', 'gun and car',
#        'vehicle', 'pellet gun', 'BB gun', 'incendiary device',
#        'samurai sword', 'bow and arrow', 'gun and vehicle',
#        'vehicle and gun', 'wrench', 'walking stick', 'barstool'],
#       dtype=object)

# %%
#Now I am replacing all of the armed df with just armed.
df4 = df4.replace(armed_df, "armed")

# %%
df4.head()
# Out:
#      armed   age gender race           city  signs_of_mental_illness  \
# 0    armed  53.0      M    A        Shelton                     True
# 1    armed  47.0      M    W          Aloha                    False
# 2  unarmed  23.0      M    H        Wichita                    False
# 3    armed  32.0      M    W  San Francisco                     True
# 4    armed  39.0      M    H          Evans                    False
#
#   threat_level         flee  body_camera  year
# 0       attack  Not fleeing        False  2015
# 1       attack  Not fleeing        False  2015
# 2        other  Not fleeing        False  2015
# 3       attack  Not fleeing        False  2015
# 4       attack  Not fleeing        False  2015

# %% [markdown]
# ### Data Modeling - Shootings by Ethnicty

# %%
#Plotting shootings by ethnicity
#Using df2 to include all rows that have a race value.

ethnicity_vals = df2.race.value_counts()

(ethnicity_vals/df.shape[0]).plot(kind="bar");
plt.title("Police Shooting by Ethnicty");

# %%
#adding population data from Kaiser Family Foundation
ethnicity_vals_percent = pd.DataFrame(ethnicity_vals/df.shape[0])
ethnicity_vals_percent.insert(1, "Population", [.61, .12, .18, .05, .013, .007], True) 

ethnicity_vals_percent
# Out:
#        race  Population
# W  0.460139       0.610
# B  0.239838       0.120
# H  0.174938       0.180
# A  0.016843       0.050
# N  0.016169       0.013
# O  0.008983       0.007

# %%
ethnicity_vals_percent.plot(kind="bar");
plt.title("Police Shooting by Ethnicty");
plt.legend(('Shootings','Population'))

# %%
#filtering the data to unarmed, not fleeing, not attacking incidents.
df_filtered_rows = df4.query('threat_level != "attack"') 
df_filtered_rows = df_filtered_rows.query('threat_level != "armed"') 
df_filtered_rows = df_filtered_rows.query('armed != "armed"') 
df_filtered_rows = df_filtered_rows.query('flee == "Not fleeing"') 

df_filtered_rows
# Out:
#         armed   age gender race              city  signs_of_mental_illness  \
# 2     unarmed  23.0      M    H           Wichita                    False
# 8     unarmed  34.0      F    W        Burlington                    False
# 86    unarmed  28.0      M    H             Tempe                    False
# 107   unarmed  35.0      M    H           Reading                    False
# 112   unarmed  25.0      M    B     Miami Gardens                     True
# 125   unarmed  31.0      M    H            Euless                    False
# 132   unarmed  39.0      M    W             Omaha                    False
# 140   unarmed  31.0      M    W       Terre Haute                    False
# 143   unarmed  49.0      M    W          Gulfport                    False
# 159   unarmed  26.0      M    W           Deltona                    False
# 174   unarmed  27.0      M    B           Atlanta                     True
# 186   unarmed  35.0      M    B        Washington                     True
# 249   unarmed  44.0      M    B             Tulsa                    False
# 306   unarmed  19.0      M    H        Long Beach                    False
# 327   unarmed  42.0      M    O         San Diego                     True
# 387   unarmed  20.0      M    O        Long Beach                    False
# 446   unarmed  24.0      M    H             Azusa                     True
# 457   unarmed  41.0      M    B      Owings Mills                     True
# 482   unarmed  43.0      M    W  Hawaiian Gardens                    False
# 538   unarmed  47.0      M    W             White                    False
# 586   unarmed  19.0      M    B         Arlington                    False
# 655   unarmed  61.0      M    B      Mount Vernon                    False
# 754   unarmed  27.0      M    O             Akron                    False
# 873   unarmed  58.0      M    W         Arlington                    False
# 975   unarmed  35.0      M    B          Dearborn                     True
# 993   unarmed  23.0      M    B         Las Vegas                    False
# 1017  unarmed  12.0      F    W     Penn Township                    False
# 1036  unarmed  26.0      M    W              Mesa                    False
# 1082  unarmed  36.0      M    B       San Antonio                    False
# 1095  unarmed  17.0      M    B            Austin                    False
# ...       ...   ...    ...  ...               ...                      ...
# 1907  unarmed  73.0      M    H       Bakersfield                    False
# 2060  unarmed  23.0      M    H          Moultrie                    False
# 2077  unarmed  26.0      M    W   Geneva Township                    False
# 2194  unarmed  21.0      F    B           Gifford                    False
# 2319  unarmed  35.0      M    W    Baldwin County                    False
# 2427  unarmed  17.0      M    H          Palmdale                    False
# 2472  unarmed  27.0      M    B             Mamou                    False
# 2708  unarmed  35.0      M    W             Hiram                    False
# 2826  unarmed  29.0      M    A     Oklahoma City                     True
# 2908  unarmed   6.0      M    W           Schertz                    False
# 2931  unarmed  28.0      M    W           Wichita                    False
# 2966  unarmed  51.0      M    W            Sedona                     True
# 2993  unarmed  16.0      M    W   Franklin County                    False
# 3001  unarmed  61.0      M    B          Longview                     True
# 3009  unarmed  37.0      M    W          Sallisaw                    False
# 3021  unarmed  47.0      M    H           Houston                    False
# 3038  unarmed  40.0      M    W              Pink                    False
# 3058  unarmed  59.0      M    W     St. Augustine                    False
# 3148  unarmed  84.0      F    W      Bexar County                    False
# 3435  unarmed  41.0      M    B     Silver Spring                     True
# 3438  unarmed  34.0      M    W           Phoenix                    False
# 3563  unarmed  56.0      M    W            Havasu                     True
# 3712  unarmed  33.0      M    W           Orlando                     True
# 3751  unarmed  18.0      M    B       San Antonio                    False
# 3808  unarmed  52.0      M    W           Wagoner                    False
# 3984  unarmed  18.0      M    B            Aurora                    False
# 4008  unarmed  24.0      F    W         St. Louis                    False
# 4165  unarmed  57.0      M    B         Baltimore                    False
# 4197  unarmed  37.0      M    W         Kalamazoo                     True
# 4301  unarmed  41.0      M    W        Montgomery                    False
#
#      threat_level         flee  body_camera  year
# 2           other  Not fleeing        False  2015
# 8           other  Not fleeing         True  2015
# 86          other  Not fleeing        False  2015
# 107         other  Not fleeing        False  2015
# 112         other  Not fleeing        False  2015
# 125         other  Not fleeing        False  2015
# 132         other  Not fleeing        False  2015
# 140         other  Not fleeing        False  2015
# 143         other  Not fleeing        False  2015
# 159         other  Not fleeing        False  2015
# 174         other  Not fleeing        False  2015
# 186         other  Not fleeing        False  2015
# 249         other  Not fleeing        False  2015
# 306         other  Not fleeing        False  2015
# 327         other  Not fleeing         True  2015
# 387         other  Not fleeing        False  2015
# 446         other  Not fleeing        False  2015
# 457         other  Not fleeing        False  2015
# 482         other  Not fleeing        False  2015
# 538         other  Not fleeing        False  2015
# 586         other  Not fleeing        False  2015
# 655         other  Not fleeing        False  2015
# 754         other  Not fleeing        False  2015
# 873         other  Not fleeing        False  2015
# 975         other  Not fleeing        False  2015
# 993         other  Not fleeing         True  2015
# 1017        other  Not fleeing        False  2016
# 1036        other  Not fleeing         True  2016
# 1082        other  Not fleeing        False  2016
# 1095        other  Not fleeing        False  2016
# ...           ...          ...          ...   ...
# 1907        other  Not fleeing        False  2016
# 2060        other  Not fleeing        False  2017
# 2077        other  Not fleeing        False  2017
# 2194        other  Not fleeing        False  2017
# 2319        other  Not fleeing        False  2017
# 2427        other  Not fleeing        False  2017
# 2472        other  Not fleeing        False  2017
# 2708        other  Not fleeing        False  2017
# 2826        other  Not fleeing         True  2017
# 2908        other  Not fleeing        False  2017
# 2931        other  Not fleeing        False  2017
# 2966        other  Not fleeing        False  2018
# 2993        other  Not fleeing        False  2018
# 3001        other  Not fleeing        False  2018
# 3009        other  Not fleeing        False  2018
# 3021        other  Not fleeing        False  2018
# 3038        other  Not fleeing        False  2018
# 3058        other  Not fleeing        False  2018
# 3148        other  Not fleeing        False  2018
# 3435        other  Not fleeing         True  2018
# 3438        other  Not fleeing        False  2018
# 3563        other  Not fleeing         True  2018
# 3712        other  Not fleeing        False  2018
# 3751        other  Not fleeing        False  2018
# 3808        other  Not fleeing        False  2018
# 3984        other  Not fleeing        False  2019
# 4008        other  Not fleeing        False  2019
# 4165        other  Not fleeing         True  2019
# 4197        other  Not fleeing        False  2019
# 4301        other  Not fleeing        False  2019
#
# [67 rows x 10 columns]

# %%
ethnicity_vals2 = df_filtered_rows.race.value_counts()

ethnicity_vals_percent2 = pd.DataFrame(ethnicity_vals2/df_filtered_rows.shape[0])
ethnicity_vals_percent2.insert(1, "Population", [.61, .125, .18, .007, .05], True) 

ethnicity_vals_percent2
# Out:
#        race  Population
# W  0.462687       0.610
# B  0.298507       0.125
# H  0.179104       0.180
# O  0.044776       0.007
# A  0.014925       0.050

# %%
ethnicity_vals_percent2.plot(kind="bar");
plt.title("Police Shooting by Ethnicty");

# %%
#I am curious where these shootings are most often occuring
state_vals = df2.state.value_counts()

(state_vals).plot(kind="bar");
plt.title("Police Shooting by State");

# %% [markdown]
# # Clustering

# %%
###Further data preparation for clustering. We must handle all of the categorical values using get_dummies.

# %%
#Dropping columns that are not valuable usefull for the analysis
df4= df4.drop(['city'],axis=1)

# %%
#Identify categorical columns
cat_df = df4.select_dtypes(include=['object'])
cat_df.shape[1]
# Out:
# 5

# %%
#apply get_dummies
cat_cols_lst = cat_df.columns

def create_dummy_df(df, cat_cols, dummy_na):
    """Use get_dummies on your categorical variables"""

    for col in  cat_cols:
        try:
            # for each cat add dummy var, drop original column
            df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

# %%
cat_df = df4.select_dtypes(include=['object'])
cat_cols_lst = cat_df.columns

df_new = create_dummy_df(df4, cat_cols_lst, dummy_na=False) #Use your newly created function

# Show a header of df_new to check
print(df_new.shape)
# Out:
# (3644, 16)

# %%
#Test KMeans score
def get_kmeans_score(data, center):
    """"Test KMeans score for a range of # of centers"""
    kmeans=KMeans(n_clusters=center)
    model = kmeans.fit(df_new)
    score = np.abs(model.score(df_new))
    return score

scores = []
centers = list(range(1,10))

for center in centers:
    scores.append(get_kmeans_score(df_new, center))
    
plt.plot(centers, scores, linestyle = '--', marker = 'o', color = 'b');
plt.xlabel('K');
plt.ylabel('SSE');
plt.title('SSEvs. K');

# %%
#Run KMeans
kmeans = KMeans(4)
model = kmeans.fit(df_new)
labels = model.predict(df_new)

# %%
#h.plot_data(df_new, labels)

# %%
###Evaluating results of KMeans

# %%
df_new1 = df_new[labels == 1]

# %%
df_new1.describe()
# Out:
#               age         year  armed_unarmed    gender_M      race_B  \
# count  381.000000   381.000000      381.00000  381.000000  381.000000
# mean    61.868766  2016.724409        0.03937    0.963255    0.131234
# std      6.429668     1.311952        0.19473    0.188383    0.338100
# min     55.000000  2015.000000        0.00000    0.000000    0.000000
# 25%     57.000000  2016.000000        0.00000    1.000000    0.000000
# 50%     60.000000  2017.000000        0.00000    1.000000    0.000000
# 75%     65.000000  2018.000000        0.00000    1.000000    0.000000
# max     91.000000  2019.000000        1.00000    1.000000    1.000000
#
#            race_H  race_N      race_O      race_W  threat_level_attack  \
# count  381.000000   381.0  381.000000  381.000000           381.000000
# mean     0.086614     0.0    0.002625    0.761155             0.713911
# std      0.281639     0.0    0.051232    0.426939             0.452526
# min      0.000000     0.0    0.000000    0.000000             0.000000
# 25%      0.000000     0.0    0.000000    1.000000             0.000000
# 50%      0.000000     0.0    0.000000    1.000000             1.000000
# 75%      0.000000     0.0    0.000000    1.000000             1.000000
# max      1.000000     0.0    1.000000    1.000000             1.000000
#
#        threat_level_other   flee_Foot  flee_Not fleeing  flee_Other
# count          381.000000  381.000000        381.000000  381.000000
# mean             0.259843    0.041995          0.895013    0.007874
# std              0.439125    0.200841          0.306940    0.088502
# min              0.000000    0.000000          0.000000    0.000000
# 25%              0.000000    0.000000          1.000000    0.000000
# 50%              0.000000    0.000000          1.000000    0.000000
# 75%              1.000000    0.000000          1.000000    0.000000
# max              1.000000    1.000000          1.000000    1.000000

# %%
df_new1 = df_new[labels == 3]

# %%
df_new1.describe()
# Out:
#               age         year  armed_unarmed    gender_M      race_B  \
# count  839.000000   839.000000     839.000000  839.000000  839.000000
# mean    46.818832  2016.702026       0.050060    0.946365    0.169249
# std      3.957480     1.326932       0.218198    0.225431    0.375195
# min     41.000000  2015.000000       0.000000    0.000000    0.000000
# 25%     43.000000  2015.000000       0.000000    1.000000    0.000000
# 50%     47.000000  2017.000000       0.000000    1.000000    0.000000
# 75%     50.000000  2018.000000       0.000000    1.000000    0.000000
# max     54.000000  2019.000000       1.000000    1.000000    1.000000
#
#            race_H      race_N      race_O      race_W  threat_level_attack  \
# count  839.000000  839.000000  839.000000  839.000000           839.000000
# mean     0.147795    0.011919    0.010727    0.640048             0.660310
# std      0.355108    0.108586    0.103076    0.480272             0.473886
# min      0.000000    0.000000    0.000000    0.000000             0.000000
# 25%      0.000000    0.000000    0.000000    0.000000             0.000000
# 50%      0.000000    0.000000    0.000000    1.000000             1.000000
# 75%      0.000000    0.000000    0.000000    1.000000             1.000000
# max      1.000000    1.000000    1.000000    1.000000             1.000000
#
#        threat_level_other   flee_Foot  flee_Not fleeing  flee_Other
# count          839.000000  839.000000        839.000000  839.000000
# mean             0.311085    0.089392          0.764005    0.027414
# std              0.463213    0.285479          0.424872    0.163383
# min              0.000000    0.000000          0.000000    0.000000
# 25%              0.000000    0.000000          1.000000    0.000000
# 50%              0.000000    0.000000          1.000000    0.000000
# 75%              1.000000    0.000000          1.000000    0.000000
# max              1.000000    1.000000          1.000000    1.000000

# %%
#Create data set with mean on each column for each label.
df_label_1 = pd.DataFrame(df_new[labels ==3].mean(axis=0) )
df_label_1.insert(1, "Label1", df_new[labels ==1].mean(axis=0), True)
df_label_1.insert(1, "Label2", df_new[labels ==2].mean(axis=0), True)
df_label_1
# Out:
#                                    0       Label2       Label1
# age                        46.818832    23.125445    61.868766
# signs_of_mental_illness     0.265793     0.201068     0.349081
# body_camera                 0.101311     0.123665     0.115486
# year                     2016.702026  2016.678826  2016.724409
# armed_unarmed               0.050060     0.108541     0.039370
# gender_M                    0.946365     0.958185     0.963255
# race_B                      0.169249     0.361210     0.131234
# race_H                      0.147795     0.217082     0.086614
# race_N                      0.011919     0.022242     0.000000
# race_O                      0.010727     0.013345     0.002625
# race_W                      0.640048     0.367438     0.761155
# threat_level_attack         0.660310     0.636121     0.713911
# threat_level_other          0.311085     0.312278     0.259843
# flee_Foot                   0.089392     0.203737     0.041995
# flee_Not fleeing            0.764005     0.591637     0.895013
# flee_Other                  0.027414     0.038256     0.007874

# %%
#Plot the mean for each label
df_label_1= df_label_1.drop(['year','age'],axis=0)

df_label_1.plot(kind="bar");
plt.title("KMeans Group Averages");
plt.legend(('Group 1','Group 2','Group 3'))

# %%
#Additional modeling - Data is already understood and prepared for the correlation plot

# %%
#Correlation plot on cleaned data
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_new.corr(), annot=True, fmt='.2f');
